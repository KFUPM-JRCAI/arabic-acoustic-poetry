# %%
# !git clone https://github.com/huggingface/transformers.git
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 89521, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 89521 (delta 0), reused 6 (delta 0), pack-reused 89515
# Receiving objects: 100% (89521/89521), 72.42 MiB | 29.63 MiB/s, done.
# Resolving deltas: 100% (64574/64574), done.

# %%
# %cd /content/transformers/examples/research_projects/wav2vec2
# !pip install -r requirements.txt
# Out:
# /content/transformers/examples/research_projects/wav2vec2
# ...
#      |████████████████████████████████| 3.1 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 290 kB 64.8 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 39.8 MB/s
# ...
#      |████████████████████████████████| 183 kB 60.0 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 895 kB 47.9 MB/s
# ...
#      |████████████████████████████████| 59 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 54.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 34.8 MB/s
# ...
#      |████████████████████████████████| 132 kB 54.7 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 48.3 MB/s
# ...
#      |████████████████████████████████| 243 kB 52.5 MB/s
# ...
#      |████████████████████████████████| 160 kB 64.5 MB/s
# ...
#      |████████████████████████████████| 192 kB 68.6 MB/s
# ...
#      |████████████████████████████████| 271 kB 62.8 MB/s
# ...

# %%
# !python run_asr.py \
--output_dir="./wav2vec2-large-xlsr-53-arabic-speech-corpus" \
--num_train_epochs="50" \
--per_device_train_batch_size="1" \
--per_device_eval_batch_size="1" \
--gradient_accumulation_steps="8" \
--evaluation_strategy="steps" \
--save_steps="500" \
--eval_steps="100" \
--logging_steps="50" \
--learning_rate="5e-4" \
--warmup_steps="3000" \
--model_name_or_path="elgeish/wav2vec2-large-xlsr-53-arabic" \
--fp16 \
--dataset_name="arabic_speech_corpus" \
--train_split_name="train" \
--validation_split_name="test" \
--max_duration_in_seconds="15" \
--orthography="buckwalter" \
--preprocessing_num_workers="$(nproc)" \
--group_by_length \
--freeze_feature_extractor \
--target_feature_extractor_sampling_rate \
--verbose_logging \
# Out:
# Streaming output truncated to the last 5000 lines.
#  19% 16/83 [00:03<00:16,  4.02it/s]
#  20% 17/83 [00:03<00:15,  4.24it/s]
#  22% 18/83 [00:03<00:16,  3.99it/s]
#  23% 19/83 [00:04<00:15,  4.00it/s]
#  24% 20/83 [00:04<00:15,  4.03it/s]
#  25% 21/83 [00:04<00:14,  4.24it/s]
#  27% 22/83 [00:04<00:15,  3.90it/s]
#  28% 23/83 [00:05<00:15,  3.91it/s]
#  29% 24/83 [00:05<00:16,  3.64it/s]
#  30% 25/83 [00:05<00:14,  3.95it/s]
#  31% 26/83 [00:05<00:14,  3.81it/s]
#  33% 27/83 [00:06<00:16,  3.37it/s]
#  34% 28/83 [00:06<00:13,  4.20it/s]
#  35% 29/83 [00:06<00:12,  4.28it/s]
#  36% 30/83 [00:06<00:12,  4.28it/s]
#  37% 31/83 [00:07<00:11,  4.66it/s]
#  39% 32/83 [00:07<00:11,  4.61it/s]
#  40% 33/83 [00:07<00:10,  4.64it/s]
#  41% 34/83 [00:07<00:10,  4.52it/s]
#  42% 35/83 [00:08<00:12,  3.90it/s]
#  43% 36/83 [00:08<00:11,  3.92it/s]
#  45% 37/83 [00:08<00:11,  3.87it/s]
#  46% 38/83 [00:08<00:12,  3.72it/s]
#  47% 39/83 [00:09<00:11,  3.86it/s]
# ...
